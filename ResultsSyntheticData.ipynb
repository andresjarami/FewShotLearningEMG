# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA
import Experiments.DatabasesEvaluation.functions as F
# %matplotlib notebook

# %%
seed = 1
samples = 500
people = 5
Graph = True
covRandom = False
nameFile = None
mix = False

DataFrame = F.DataGenerator_TwoCL_TwoFeat(seed, samples, people, Graph, covRandom, nameFile, mix)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
nameFile = None
shots = 50
Features = 2
classes = 2
times = 100
Graph = True

F.ResultsSyntheticData(DataFrame, nameFile, shots, people, samples, Features, classes, times, Graph)
