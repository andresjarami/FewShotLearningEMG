# %% [markdown]
# # Experiment 3
#
# In this experiment, we compare the proposed adaptive interface’s accuracy using our technique and an adaptive myoelectric interface using CNN and transfer learning, proposed by [Côté-Allard et al.](https://github.com/UlysseCoteAllard/MyoArmbandDataset). Côté-Allard interface assists the CNN training for a user taking advantage of a CNN trained using EMG data from the source users. The following table shows the accuracy of our adaptive interface and the Côté-Allard interface, and the difference between them. In this table, the differences were calculated as experiment 1 using the one-tail Wilcoxon signed-rank test. The only negative difference is not statistically significant and six differences are positive and statistically significant. Consequently, our interface’s accuracy is higher than or equal to the Côté-Allard interface’s accuracy.

# %% [markdown]
# ## Import the library developed to visualize the results

# %%
import Experiments.Experiment3.VisualizationFunctions as VF3

# %% [markdown]
# ## Accuracy Comparison in percentage between Côté-Allard interface and Our QDA interface using the Feature Set 1 and the Three Database

# %%
placeCoteResults="Experiments/Experiment3/"
placeOurTechniqueResults="Experiments/Experiment1/ResultsExp1/"
VF3.AnalysisCote(placeOurTechniqueResults,placeCoteResults)
# Out:
#                                                             0          1  \
# Our Interface's accuracy [%] over database: Nin...  50.560000  57.500000
# Cote Interface's accuracy [%] over database: Ni...  44.760000  55.200000
# Difference [%] over database: NinaPro5               5.810000   2.310000
# p-value over database: NinaPro5                      0.002531   0.002531
# Our Interface's accuracy [%] over database: Cote    96.530000  99.200000
# Cote Interface's accuracy [%] over database: Cote   96.130000  99.000000
# Difference [%] over database: Cote                   0.400000   0.200000
# p-value over database: Cote                          1.000000   1.000000
# Our Interface's accuracy [%] over database: EPN     74.930000  82.600000
# Cote Interface's accuracy [%] over database: EPN    68.490000  77.760000
# Difference [%] over database: EPN                    6.430000   4.840000
# p-value over database: EPN                           0.000041   0.003418
#
#                                                             2          3
# Our Interface's accuracy [%] over database: Nin...  63.060000  65.180000
# Cote Interface's accuracy [%] over database: Ni...  59.870000  62.520000
# Difference [%] over database: NinaPro5               3.190000   2.670000
# p-value over database: NinaPro5                      0.002531   0.004672
# Our Interface's accuracy [%] over database: Cote    99.410000  99.090000
# Cote Interface's accuracy [%] over database: Cote   99.000000  99.430000
# Difference [%] over database: Cote                   0.410000  -0.340000
# p-value over database: Cote                          1.000000   1.000000
# Our Interface's accuracy [%] over database: EPN     82.310000  83.140000
# Cote Interface's accuracy [%] over database: EPN    79.360000  82.300000
# Difference [%] over database: EPN                    2.950000   0.830000
# p-value over database: EPN                           1.000000   1.000000

# %%
placeCoteResults="Experiments/Experiment3/"
placeOurTechniqueResults="Experiments/Experiment1/results260/"
VF3.AnalysisCote(placeOurTechniqueResults,placeCoteResults)
# Out:
#                                                             0          1  \
# Our Interface's accuracy [%] over database: Nin...  49.870000  56.860000
# Cote Interface's accuracy [%] over database: Ni...  44.760000  55.200000
# Difference [%] over database: NinaPro5               5.110000   1.660000
# p-value over database: NinaPro5                      0.008302   0.003455
# Our Interface's accuracy [%] over database: Cote    96.670000  99.060000
# Cote Interface's accuracy [%] over database: Cote   96.130000  99.000000
# Difference [%] over database: Cote                   0.540000   0.060000
# p-value over database: Cote                          1.000000   1.000000
# Our Interface's accuracy [%] over database: EPN     74.880000  80.200000
# Cote Interface's accuracy [%] over database: EPN    68.490000  77.760000
# Difference [%] over database: EPN                    6.390000   2.440000
# p-value over database: EPN                           0.000386   1.000000
#
#                                                             2          3
# Our Interface's accuracy [%] over database: Nin...  61.670000  64.320000
# Cote Interface's accuracy [%] over database: Ni...  59.870000  62.520000
# Difference [%] over database: NinaPro5               1.800000   1.800000
# p-value over database: NinaPro5                      0.023427   0.029668
# Our Interface's accuracy [%] over database: Cote    99.420000  99.250000
# Cote Interface's accuracy [%] over database: Cote   99.000000  99.430000
# Difference [%] over database: Cote                   0.420000  -0.180000
# p-value over database: Cote                          1.000000   1.000000
# Our Interface's accuracy [%] over database: EPN     80.970000  82.380000
# Cote Interface's accuracy [%] over database: EPN    79.360000  82.300000
# Difference [%] over database: EPN                    1.610000   0.070000
# p-value over database: EPN                           1.000000   1.000000

# %%
c=[65.57,62.21,57.53,48.33,98.31,97.82,96.63,94.69,68.490000,77.760000,79.360000,82.300000]
o=[49.870000,56.860000,61.670000,64.320000,96.670000	99.060000	99.420000	99.250000]
