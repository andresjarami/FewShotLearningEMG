# %%
import Experiments.DatabasesEvaluation.functions as F

# %% [markdown]
# # A example of different, similar and target user

# %%
F.DataGenerator_TwoCL_TwoFeatEXAMPLE()

# %% [markdown]
# # Graphs of the DA-based adaptive classifiers

# %%
F.graphSyntheticDataALL()
